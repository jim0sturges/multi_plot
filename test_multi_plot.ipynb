# %%
from datetime import date
import pandas as pd
from multi_plot import multi_plot     #multi_plot in same directory
# %matplotlib inline
import matplotlib.pylab as plt
from IPython.display import display
import matplotlib.dates as mdates
start_date = date(2011, 5, 3)
end_date = date(2011, 5, 6)
L=pd.date_range(start='1/1/2018', end='1/3/2018').tolist()
df=pd.DataFrame({'date':L,
                 'key':[213,4,65],
                 'new':[98,29,17], 
                 'old':[2,56,22],
                 'young':[8,25,29], 
                 'red':[77,21,13],
                 'white':[1,9,99],
                 'blue':[87,22,31]})
df=df.set_index('date')
display(df)
multi_plot(df)
# Out:
#             key  new  old  young  red  white  blue
# date
# 2018-01-01  213   98    2      8   77      1    87
# 2018-01-02    4   29   56     25   21      9    22
# 2018-01-03   65   17   22     29   13     99    31
